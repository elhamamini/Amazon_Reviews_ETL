# %%
import pandas as pd
import numpy as np

yes_col = []
no_list = []
perc_row = []

url = 'Resources/vine_table.csv'

# %%
vine_df = pd.read_csv(url, index_col=False, header=None)
vine_df.col_names = [review_id,]

# %%
vine_df.head(20)
# Out:
#                  0    1    2    3  4  5
# 0    R3EQSTM9PWRAL  3.0  0.0  0.0  N  Y
# 1    RBWPRK17XKIXD  5.0  0.0  0.0  N  Y
# 2    RRSLOAF273XFC  5.0  1.0  2.0  N  Y
# 3   R3S8W9Q6SWIT8O  4.0  0.0  0.0  N  Y
# 4   R3QQ6NSLRVBFJC  4.0  0.0  0.0  N  Y
# 5   R2XYDBMHUVJCSX  2.0  0.0  1.0  N  Y
# 6   R1L94ESVC657A9  5.0  0.0  0.0  N  Y
# 7   R3DI4B8LDWFQ3K  1.0  3.0  4.0  N  Y
# 8   R1G7VV4HCXUQQL  5.0  0.0  0.0  N  Y
# 9   R3TTNYN1TAMUSU  5.0  0.0  0.0  N  Y
# 10  R3AMX2D9HMWV6Z  5.0  0.0  0.0  N  Y
# 11  R3PO3K321GY8HI  1.0  0.0  0.0  N  Y
# 12   RVQ0UNYX6IEVK  1.0  0.0  1.0  N  Y
# 13  R25E9NIGO2XQ3D  5.0  0.0  0.0  N  Y
# 14  R3GIEXIIIR2G9Y  1.0  0.0  0.0  N  Y
# 15  R264BH3U417NXF  5.0  0.0  0.0  N  Y
# 16  R2C6S0XJIMP0Z2  5.0  0.0  0.0  N  Y
# 17  R2LRJYGC2YYR2F  2.0  0.0  0.0  N  Y
# 18  R3SVW9ZP1CZPW7  1.0  0.0  1.0  N  Y
# 19  R1GLA6RQUF4Q79  4.0  0.0  0.0  N  Y
